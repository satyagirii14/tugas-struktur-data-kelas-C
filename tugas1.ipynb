# %% [markdown]
# <a href="https://colab.research.google.com/github/satyagirii14/tugas-struktur-data-kelas-C/blob/main/tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nilai = []
print("masukkan 10 nilai:")
for i in range(10):
  n = int(input("nilai ke-" + str(i+1) + ":"))
  nilai.append(n)

max_nilai = max(nilai)
min_nilai = min(nilai)
rata = sum(nilai)/len(nilai)
lulus = sum(1 for n in nilai if n >= 60)
tidak_lulus = len(nilai) - lulus

print("\n=== HASIL PENGOLAHAN ===")
print("semua nilai:", nilai)
print("nilai terbesar:", max_nilai)
print("nilai terkecil:", min_nilai)
print("nilai rata-rata:", rata)
print("jumlah lulus:", lulus)
print("jumlah tidak lulus:", tidak_lulus)
# Out:
# masukkan 10 nilai:
# nilai ke-1:40
# nilai ke-2:45
# nilai ke-3:50
# nilai ke-4:60
# nilai ke-5:65
# nilai ke-6:70
# nilai ke-7:80
# nilai ke-8:90
# nilai ke-9:95
# nilai ke-10:100
#
# === HASIL PENGOLAHAN ===
# semua nilai: [40, 45, 50, 60, 65, 70, 80, 90, 95, 100]
# nilai terbesar: 100
# nilai terkecil: 40
# nilai rata-rata: 69.5
# jumlah lulus: 7
# jumlah tidak lulus: 3

# %%
from google.colab import drive
drive.mount('/content/drive')
